# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('Iris.csv')
df.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# extract the x and y
x = df.drop(columns=['Species'])
y = df['Species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.compose import ColumnTransformer

trf1 = ColumnTransformer(
    [
        ('standard', StandardScaler(), slice(0,4))
    ]
)

# %%
from sklearn.tree import DecisionTreeClassifier
trf2 = DecisionTreeClassifier()

# %%
pip = Pipeline(
    [
        ('trf1', trf1),
        ('trf2', trf2)
    ]
)

# %%
from sklearn.metrics import accuracy_score

pip.fit(x_train,y_train)
pred = pip.predict(x_test)
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
from sklearn.decomposition import PCA

# %%
trf3 = PCA(n_components=2)

pipe2 = Pipeline([
    ('trf1', trf1),
    ('trf3', trf3),
    ('trf2', trf2)
])

# %%
pipe2.fit(x_train,y_train)
pred = pipe2.predict(x_test)
print(accuracy_score(y_test, pred))

pipe2.named_steps
# Out:
# 1.0
# {'trf1': ColumnTransformer(transformers=[('standard', StandardScaler(),
#                                   slice(0, 4, None))]),
#  'trf3': PCA(n_components=2),
#  'trf2': DecisionTreeClassifier()}

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
print(trf3.components_)
# Out:
# [[ 0.55370393  0.5108737  -0.2960881   0.58715574]
#  [-0.01956688  0.44927208  0.88991485  0.07631054]]

# %%
trf3.explained_variance_
# Out:
# array([2.81635968, 0.93173122])

# %%
trf3.explained_variance_ratio_
# Out:
# array([0.6982225, 0.2309917])
